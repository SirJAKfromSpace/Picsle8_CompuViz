# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.utils import save_image

from PIL import Image
import matplotlib.pyplot as plt

import copy

from pytorch_datasetloader import *

# %% [markdown]
# # The Discriminator

# %%
class Dis(nn.Module):
    
    
    def __init__(self):
        
        super().__init__()
        
        #block 1 input = 3*128*128 
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=3,out_channels=15, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        
        #block 2 input = 15*64*64
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=15,out_channels=50, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        
        #block 3 input = 50*32*32
        self.layer3 = nn.Sequential(
            nn.Conv2d(in_channels=50,out_channels=200, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        
     
        #self.drop_out = nn.Dropout()
        self.fc1 = torch.nn.Linear(200*16*16, 120)
        self.fc2 = torch.nn.Linear(120, 60)
        
        self.outlayer = nn.Sequential(
            nn.Linear(60, 1),
            nn.Sigmoid()
        )
        
        
        
    def forward(self, x):
        

        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.reshape(out.size(0), -1)
        #out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.outlayer(out)
        
        
        return(out)

# %% [markdown]
# # The Generator

# %%
#pooling for rescaling was avoided in favor of strided convolutions
#based on following paper: https://arxiv.org/pdf/1606.03498.pdf
class Gen(nn.Module):
    

    
    def __init__(self):
        
        super().__init__()
        

        self.encode = nn.Sequential(
            
            #encoding 1
            nn.Conv2d(in_channels=3,out_channels=15, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(15),
            
            #encoding 2
            nn.Conv2d(in_channels=15,out_channels=50, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(50),
            
            #encoding 3
            nn.Conv2d(in_channels=50,out_channels=200, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(200)
            
            
        )
        
        
        self.decode = nn.Sequential(
            
            #decoding 1
            nn.ConvTranspose2d(in_channels=200,out_channels=50, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(50),
            
            #decoding 2
            nn.ConvTranspose2d(in_channels=50,out_channels=15, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(15),
            
            #decoding 3
            nn.ConvTranspose2d(in_channels=15,out_channels=3, kernel_size=4, stride=2, padding=1)
        )
        
        
        
        
    def forward(self, x):
        

        out = self.encode(x)
        out = self.decode(out)
  
        return(out)

# %%
#using cuda if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

D = Dis()
D = D.to(device)

G = Gen()
G = G.to(device)
# Out:
# cuda:0

# %% [markdown]
# # Loading Dataset

# %%
batch_size_Realpix = 32
batch_size_mixed = 64
dataset_len =  100

path = 'RealPix_224'
trainloader_nonpixel, validloader_nonpixel = get_loaders(path,batch_size=batch_size_Realpix)

path = 'mixed'
trainloader_pixel, validloader_pixel = get_loaders(path,batch_size=batch_size_mixed)


trainiter_nonpixel = iter(trainloader_nonpixel)
trainIter_pixel = iter(trainloader_pixel)
# Out:
# 224 images from the dataset
# 448 images from the dataset

# %% [markdown]
# # Selecting Optimizer

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %% [markdown]
# # Training the DCGAN

# %%
# Train the model
total_step = len(trainloader_pixel)
d_loss_list = []
g_loss_list = []
acc_list = []
num_epochs = 1000
sample_imflag = 0

for epoch in range(num_epochs):
    
    trainiter_nonpixel = iter(trainloader_nonpixel)
    trainIter_pixel = iter(trainloader_pixel)
    
    for i in range(2):
        
        images, labels = trainIter_pixel.next()
        inputImages, input_lbls = trainiter_nonpixel.next()
        
        
        images = images.to(device)
        inputImages = inputImages.to(device)
        
        labels = torch.tensor(labels, dtype=torch.float, device=device)
        
        # Run the forward pass
        real_classification = D(images) 
        d_loss_real = criterion(real_classification, labels)
        fake_images = G(inputImages)
        
        fake_classification = D(fake_images)
        
        fake_lbls = torch.zeros(len(input_lbls))
        fake_lbls = fake_lbls.to(device)
        
        d_loss_fake = criterion(fake_classification, fake_lbls)
        d_loss = d_loss_real + d_loss_fake
        
        
        

        # Backprop and perform Adam optimisation for Discriminator
        d_optimizer.zero_grad()
        d_loss.backward()
        d_optimizer.step()
        
        
        
        #Discriminator
        fake_lbls_duped = torch.ones(len(input_lbls))
        fake_lbls_duped = fake_lbls_duped.to(device)
    
        fake_images = G(inputImages)
        fake_classification = D(fake_images)
    
        #this loss denotes how well the generator duped/tricked the discriminator
        g_loss = criterion(fake_classification, fake_lbls_duped)
        
        
        
        # Backprop and perform Adam optimisation for generator
        d_optimizer.zero_grad()
        g_optimizer.zero_grad()
        g_loss.backward()
        g_optimizer.step()
        
      
    if (epoch+1) % 10 == 0:
        print('Epoch No [{}/{}] Discriminator Loss: {:.4f}, Generator Loss: {:.4f}'.format(epoch+1,num_epochs,d_loss.item(),g_loss.item()))
        #appending loss every 10 epochs
        d_loss_list.append(d_loss.item())
        g_loss_list.append(d_loss.item())
    
        # Save fake images
        fake_images = fake_images.view(fake_images.size(0), 3, 128, 128)
        save_image(fake_images.data, 'images/fakes/fake_images-%d.png' %(epoch+1))
        
        
        # Save input images
        if sample_imflag == 0:
            inputImages = inputImages.view(inputImages.size(0), 3, 128, 128)
            save_image(inputImages.data, 'images/input_images/inputImages-%d.png' %(epoch+1))
            sample_imflag = 1
    
#GANs are saved
torch.save(G.state_dict(), 'GAN_OUTs/DCGAN2_generator.pkl')
torch.save(D.state_dict(), 'GAN_OUTs/DCGAN2_discriminator.pkl')
# Out:
# Epoch No [10/1000] Discriminator Loss: 0.0037, Generator Loss: 10.0998
# Epoch No [20/1000] Discriminator Loss: 0.0034, Generator Loss: 10.0202
# Epoch No [30/1000] Discriminator Loss: 0.0027, Generator Loss: 10.7909
# Epoch No [40/1000] Discriminator Loss: 0.0021, Generator Loss: 10.8625
# Epoch No [50/1000] Discriminator Loss: 0.0025, Generator Loss: 11.2064
# Epoch No [60/1000] Discriminator Loss: 0.0022, Generator Loss: 11.1205
# Epoch No [70/1000] Discriminator Loss: 0.0024, Generator Loss: 10.8766
# Epoch No [80/1000] Discriminator Loss: 0.0021, Generator Loss: 11.1700
# Epoch No [90/1000] Discriminator Loss: 0.0023, Generator Loss: 11.1395
# Epoch No [100/1000] Discriminator Loss: 0.0025, Generator Loss: 11.0610
# Epoch No [110/1000] Discriminator Loss: 0.0023, Generator Loss: 11.3941
# Epoch No [120/1000] Discriminator Loss: 0.0020, Generator Loss: 11.7314
# Epoch No [130/1000] Discriminator Loss: 0.0020, Generator Loss: 11.5247
# Epoch No [140/1000] Discriminator Loss: 0.0023, Generator Loss: 11.4969
# Epoch No [150/1000] Discriminator Loss: 0.0023, Generator Loss: 11.2954
# Epoch No [160/1000] Discriminator Loss: 0.0018, Generator Loss: 14.9225
# Epoch No [170/1000] Discriminator Loss: 0.0006, Generator Loss: 17.3763
# Epoch No [180/1000] Discriminator Loss: 0.0010, Generator Loss: 15.0191
# Epoch No [190/1000] Discriminator Loss: 0.0007, Generator Loss: 14.3415
# Epoch No [200/1000] Discriminator Loss: 0.1041, Generator Loss: 20.6822
# Epoch No [210/1000] Discriminator Loss: 0.0337, Generator Loss: 9.5623
# Epoch No [220/1000] Discriminator Loss: 0.0232, Generator Loss: 7.6550
# Epoch No [230/1000] Discriminator Loss: 0.0376, Generator Loss: 8.2572
# Epoch No [240/1000] Discriminator Loss: 0.0329, Generator Loss: 10.2577
# Epoch No [250/1000] Discriminator Loss: 0.0069, Generator Loss: 11.2389
# Epoch No [260/1000] Discriminator Loss: 0.0212, Generator Loss: 8.0256
# Epoch No [270/1000] Discriminator Loss: 0.0172, Generator Loss: 8.3186
# Epoch No [280/1000] Discriminator Loss: 0.0131, Generator Loss: 8.6039
# Epoch No [290/1000] Discriminator Loss: 0.0128, Generator Loss: 8.7257
# Epoch No [300/1000] Discriminator Loss: 0.0112, Generator Loss: 9.1160
# Epoch No [310/1000] Discriminator Loss: 0.0112, Generator Loss: 9.5009
# Epoch No [320/1000] Discriminator Loss: 0.0125, Generator Loss: 8.8487
# Epoch No [330/1000] Discriminator Loss: 0.0416, Generator Loss: 8.7752
# Epoch No [340/1000] Discriminator Loss: 0.8128, Generator Loss: 11.9238
# Epoch No [350/1000] Discriminator Loss: 0.0036, Generator Loss: 8.9501
# Epoch No [360/1000] Discriminator Loss: 0.0091, Generator Loss: 8.7616
# Epoch No [370/1000] Discriminator Loss: 0.0078, Generator Loss: 8.4697
# Epoch No [380/1000] Discriminator Loss: 0.0073, Generator Loss: 8.5560
# Epoch No [390/1000] Discriminator Loss: 0.0073, Generator Loss: 8.6283
# Epoch No [400/1000] Discriminator Loss: 0.0066, Generator Loss: 8.9280
# Epoch No [410/1000] Discriminator Loss: 0.0077, Generator Loss: 9.1632
# Epoch No [420/1000] Discriminator Loss: 0.0077, Generator Loss: 9.5677
# Epoch No [430/1000] Discriminator Loss: 0.0068, Generator Loss: 9.7538
# Epoch No [440/1000] Discriminator Loss: 0.0069, Generator Loss: 10.0748
# Epoch No [450/1000] Discriminator Loss: 0.0064, Generator Loss: 10.9808
# Epoch No [460/1000] Discriminator Loss: 0.0054, Generator Loss: 11.0087
# Epoch No [470/1000] Discriminator Loss: 0.0064, Generator Loss: 11.1144
# Epoch No [480/1000] Discriminator Loss: 0.0113, Generator Loss: 11.3752
# Epoch No [490/1000] Discriminator Loss: 0.0048, Generator Loss: 12.0026
# Epoch No [500/1000] Discriminator Loss: 0.0117, Generator Loss: 12.2068
# Epoch No [510/1000] Discriminator Loss: 0.0074, Generator Loss: 13.8634
# Epoch No [520/1000] Discriminator Loss: 0.0216, Generator Loss: 15.2311
# Epoch No [530/1000] Discriminator Loss: 0.0094, Generator Loss: 15.9126
# Epoch No [540/1000] Discriminator Loss: 0.0077, Generator Loss: 12.9292
# Epoch No [550/1000] Discriminator Loss: 0.2899, Generator Loss: 28.3877
# Epoch No [560/1000] Discriminator Loss: 0.0073, Generator Loss: 11.5502
# Epoch No [570/1000] Discriminator Loss: 0.0017, Generator Loss: 12.0927
# Epoch No [580/1000] Discriminator Loss: 0.0049, Generator Loss: 11.4285
# Epoch No [590/1000] Discriminator Loss: 0.0036, Generator Loss: 11.3020
# Epoch No [600/1000] Discriminator Loss: 0.0025, Generator Loss: 11.6842
# Epoch No [610/1000] Discriminator Loss: 0.0023, Generator Loss: 12.1434
# Epoch No [620/1000] Discriminator Loss: 0.0023, Generator Loss: 12.6944
# Epoch No [630/1000] Discriminator Loss: 0.0025, Generator Loss: 12.7020
# Epoch No [640/1000] Discriminator Loss: 0.0029, Generator Loss: 13.7105
# Epoch No [650/1000] Discriminator Loss: 0.0023, Generator Loss: 13.2617
# Epoch No [660/1000] Discriminator Loss: 0.0030, Generator Loss: 13.0254
# Epoch No [670/1000] Discriminator Loss: 0.0027, Generator Loss: 13.1679
# Epoch No [680/1000] Discriminator Loss: 0.0020, Generator Loss: 12.9965
# Epoch No [690/1000] Discriminator Loss: 0.0022, Generator Loss: 13.5854
# Epoch No [700/1000] Discriminator Loss: 0.0028, Generator Loss: 13.8432
# Epoch No [710/1000] Discriminator Loss: 0.0031, Generator Loss: 14.3273
# Epoch No [720/1000] Discriminator Loss: 0.0025, Generator Loss: 14.0523
# Epoch No [730/1000] Discriminator Loss: 0.0022, Generator Loss: 14.4671
# Epoch No [740/1000] Discriminator Loss: 0.0023, Generator Loss: 13.5319
# Epoch No [750/1000] Discriminator Loss: 0.0030, Generator Loss: 14.6622
# Epoch No [760/1000] Discriminator Loss: 0.0035, Generator Loss: 15.5215
# Epoch No [770/1000] Discriminator Loss: 0.0027, Generator Loss: 15.8445
# Epoch No [780/1000] Discriminator Loss: 0.0030, Generator Loss: 15.6122
# Epoch No [790/1000] Discriminator Loss: 0.0022, Generator Loss: 15.0072
# Epoch No [800/1000] Discriminator Loss: 0.0038, Generator Loss: 15.1860
# Epoch No [810/1000] Discriminator Loss: 3.3846, Generator Loss: 25.5274
# Epoch No [820/1000] Discriminator Loss: 0.0791, Generator Loss: 7.2203
# Epoch No [830/1000] Discriminator Loss: 0.0382, Generator Loss: 5.8248
# Epoch No [840/1000] Discriminator Loss: 0.0196, Generator Loss: 6.4069
# Epoch No [850/1000] Discriminator Loss: 0.0175, Generator Loss: 6.8552
# Epoch No [860/1000] Discriminator Loss: 0.0144, Generator Loss: 7.2792
# Epoch No [870/1000] Discriminator Loss: 0.0119, Generator Loss: 7.6357
# Epoch No [880/1000] Discriminator Loss: 0.0113, Generator Loss: 7.9136
# Epoch No [890/1000] Discriminator Loss: 0.0110, Generator Loss: 8.3592
# Epoch No [900/1000] Discriminator Loss: 0.0097, Generator Loss: 8.6489
# Epoch No [910/1000] Discriminator Loss: 0.0115, Generator Loss: 8.8744
# Epoch No [920/1000] Discriminator Loss: 0.0086, Generator Loss: 8.9548
# Epoch No [930/1000] Discriminator Loss: 0.0073, Generator Loss: 9.4416
# Epoch No [940/1000] Discriminator Loss: 0.0075, Generator Loss: 9.3628
# Epoch No [950/1000] Discriminator Loss: 0.0073, Generator Loss: 9.3073
# Epoch No [960/1000] Discriminator Loss: 0.0065, Generator Loss: 9.3642
# Epoch No [970/1000] Discriminator Loss: 0.0064, Generator Loss: 9.2224
# Epoch No [980/1000] Discriminator Loss: 0.0067, Generator Loss: 9.4053
# Epoch No [990/1000] Discriminator Loss: 0.0059, Generator Loss: 9.5480
# Epoch No [1000/1000] Discriminator Loss: 0.0064, Generator Loss: 9.4336
